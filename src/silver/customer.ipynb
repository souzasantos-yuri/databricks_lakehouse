-- %%
SELECT
    idCustomer as customer_id,
    Pointscustomer as customer_points,
    flEmail as customer_email,
    flPhone as customer_phone,
    flAddress as customer_address,
    flCity as customer_city,
    flState as customer_state

FROM  bronze.upsell.customers
