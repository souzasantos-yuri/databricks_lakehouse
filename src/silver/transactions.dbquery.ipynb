-- %%
SELECT
    idTransaction as transaction_id,
    idCustomer as customer_id,
    dtTransaction as transaction_date,
    pointsTransaction as transaction_points
    
FROM bronze.upsell.transactions
